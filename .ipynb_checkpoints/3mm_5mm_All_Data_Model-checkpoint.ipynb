# %%
# Import Libraries -------------------------------------------------------------------------------------------------------------------------------------------------------------
import os
import h5py
import keras
import loss
import Helper
import allMetrics
import numpy as np
import tensorflow as tf
import UNetModel_3D_simplified
import matplotlib.pyplot as plt
from keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
ds_num = 2

train_fileName = f"/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/trials/numpyDatasets/numPyArrays/train_Scans/resampled_trainDS{ds_num}.hdf5"
train_maskfileName = f"/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/trials/numpyDatasets/numPyArrays/train_Mask_Scans/resampled_trainmaskDS{ds_num}.hdf5"

train_DatasetName = f"ResampledtrainScans_DataSet{ds_num}"
train_maskDatasetName = f"ResampledtrainMaskScans_DataSet{ds_num}"

valid_fileName = f"/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/trials/numpyDatasets/numPyArrays/valid_Scans/resampled_validDS{ds_num}.hdf5"
valid_maskfileName = f"/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/trials/numpyDatasets/numPyArrays/valid_Mask_Scans/resampled_validmaskDS{ds_num}.hdf5"

valid_DatasetName = f"ResampledvalidScans_DataSet{ds_num}"
valid_maskDatasetName = f"ResampledvalidMaskScans_DataSet{ds_num}"

test_fileName = f"/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/trials/numpyDatasets/numPyArrays/test_Scans/resampled_testDS{ds_num}.hdf5"
test_maskfileName = f"/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/trials/numpyDatasets/numPyArrays/test_Mask_Scans/resampled_testmaskDS{ds_num}.hdf5"

test_DatasetName = f"ResampledtestScans_DataSet{ds_num}"
test_maskDatasetName = f"ResampledtestMaskScans_DataSet{ds_num}"

# %%
with h5py.File(train_fileName, 'r') as hf: # File Dir
    train_array = hf[train_DatasetName][:]
    
with h5py.File(train_maskfileName,'r') as hf:
    train_mask_array = hf[train_maskDatasetName][:]
    
with h5py.File(valid_fileName, 'r') as hf: # File Dir
    valid_array = hf[valid_DatasetName][:]
    
with h5py.File(valid_maskfileName,'r') as hf:
    valid_mask_array = hf[valid_maskDatasetName][:]
    
with h5py.File(test_fileName, 'r') as hf: # File Dir
    test_array = hf[test_DatasetName][:]
    
with h5py.File(test_maskfileName,'r') as hf:
    test_mask_array = hf[test_maskDatasetName][:]

# %%
print(train_array.shape)
print(train_mask_array.shape)
print('--')
print(valid_array.shape)
print(valid_mask_array.shape)
print('--')
print(test_array.shape)
print(test_mask_array.shape)
# Out:
# (8889, 64, 64, 64)
# (8889, 64, 64, 64)
# --
# (2652, 64, 64, 64)
# (2652, 64, 64, 64)
# --
# (3468, 64, 64, 64)
# (3468, 64, 64, 64)

# %%
train_scan = np.concatenate((train_array,valid_array,test_array))
train_mask_scan = np.concatenate((train_mask_array,valid_mask_array,test_mask_array))

# %%
train_array = np.expand_dims(train_scan, axis=4)
train_mask_array = np.expand_dims(train_mask_scan, axis=4)

valid_array = np.expand_dims(valid_array, axis=4)
valid_mask_array = np.expand_dims(valid_mask_array, axis=4)

# %%
print(train_array.shape)
print(train_mask_array.shape)
print('--')
print(valid_array.shape)
print(valid_mask_array.shape)
# Out:
# (15009, 64, 64, 64, 1)
# (15009, 64, 64, 64, 1)
# --
# (2652, 64, 64, 64, 1)
# (2652, 64, 64, 64, 1)

# %%
LR = 0.001
opt = tf.keras.optimizers.Nadam(LR)

input_shape = (64,64,64,1)
num_class = 1

metrics = [allMetrics.dice_coef]

# %%
model = UNetModel_3D_simplified.build_unet(input_shape, n_classes = num_class)

model.compile(optimizer=opt, loss=loss.tversky_crossentropy, metrics=metrics)
print(model.summary())
# Out:
# 2023-03-15 19:10:11.324517: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-15 19:10:11.808704: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38414 MB memory:  -> device: 0, name: A100-SXM4-40GB, pci bus id: 0000:c2:00.0, compute capability: 8.0
# sigmoid
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 64,  0           []
#                                  1)]
#
#  conv3d (Conv3D)                (None, 64, 64, 64,   896         ['input_1[0][0]']
#                                 32)
#
#  batch_normalization (BatchNorm  (None, 64, 64, 64,   128        ['conv3d[0][0]']
#  alization)                     32)
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 64, 64,   0           ['batch_normalization[0][0]']
#                                 32)
#
#  conv3d_1 (Conv3D)              (None, 64, 64, 64,   27680       ['leaky_re_lu[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 64,   128        ['conv3d_1[0][0]']
#  rmalization)                   32)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 64, 64, 64,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  max_pooling3d (MaxPooling3D)   (None, 32, 32, 32,   0           ['leaky_re_lu_1[0][0]']
#                                 32)
#
#  conv3d_2 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d[0][0]']
#                                 64)
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 32,   256        ['conv3d_2[0][0]']
#  rmalization)                   64)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 32, 32, 32,   0           ['batch_normalization_2[0][0]']
#                                 64)
#
#  conv3d_3 (Conv3D)              (None, 32, 32, 32,   110656      ['leaky_re_lu_2[0][0]']
#                                 64)
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 32,   256        ['conv3d_3[0][0]']
#  rmalization)                   64)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 32, 32, 32,   0           ['batch_normalization_3[0][0]']
#                                 64)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 16, 16, 16,   0          ['leaky_re_lu_3[0][0]']
#                                 64)
#
#  conv3d_4 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_1[0][0]']
#                                 128)
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 16,   512        ['conv3d_4[0][0]']
#  rmalization)                   128)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 16, 16, 16,   0           ['batch_normalization_4[0][0]']
#                                 128)
#
#  conv3d_5 (Conv3D)              (None, 16, 16, 16,   442496      ['leaky_re_lu_4[0][0]']
#                                 128)
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 16,   512        ['conv3d_5[0][0]']
#  rmalization)                   128)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 16, 16, 16,   0           ['batch_normalization_5[0][0]']
#                                 128)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 8, 8, 8, 128  0          ['leaky_re_lu_5[0][0]']
#                                 )
#
#  conv3d_6 (Conv3D)              (None, 8, 8, 8, 256  884992      ['max_pooling3d_2[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 8, 256  1024       ['conv3d_6[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 8, 8, 8, 256  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv3d_7 (Conv3D)              (None, 8, 8, 8, 256  1769728     ['leaky_re_lu_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 8, 256  1024       ['conv3d_7[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 8, 8, 8, 256  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 4, 4, 4, 256  0          ['leaky_re_lu_7[0][0]']
#                                 )
#
#  conv3d_8 (Conv3D)              (None, 4, 4, 4, 512  3539456     ['max_pooling3d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 4, 4, 4, 512  2048       ['conv3d_8[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 4, 4, 4, 512  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 4, 4, 4, 512  7078400     ['leaky_re_lu_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 4, 4, 4, 512  2048       ['conv3d_9[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 4, 4, 4, 512  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv3d_transpose (Conv3DTransp  (None, 8, 8, 8, 256  1048832    ['leaky_re_lu_9[0][0]']
#  ose)                           )
#
#  concatenate (Concatenate)      (None, 8, 8, 8, 512  0           ['conv3d_transpose[0][0]',
#                                 )                                 'leaky_re_lu_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 8, 8, 8, 256  3539200     ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 8, 256  1024       ['conv3d_10[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 8, 8, 8, 256  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv3d_11 (Conv3D)             (None, 8, 8, 8, 256  1769728     ['leaky_re_lu_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 8, 256  1024       ['conv3d_11[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 8, 8, 8, 256  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv3d_transpose_1 (Conv3DTran  (None, 16, 16, 16,   262272     ['leaky_re_lu_11[0][0]']
#  spose)                         128)
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_1[0][0]',
#                                 256)                              'leaky_re_lu_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 16, 16, 16,   884864      ['concatenate_1[0][0]']
#                                 128)
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 16,   512        ['conv3d_12[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 16, 16, 16,   0           ['batch_normalization_12[0][0]']
#                                 128)
#
#  conv3d_13 (Conv3D)             (None, 16, 16, 16,   442496      ['leaky_re_lu_12[0][0]']
#                                 128)
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 16,   512        ['conv3d_13[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 16, 16, 16,   0           ['batch_normalization_13[0][0]']
#                                 128)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 32, 32, 32,   65600      ['leaky_re_lu_13[0][0]']
#  spose)                         64)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_2[0][0]',
#                                 128)                              'leaky_re_lu_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 32, 32, 32,   221248      ['concatenate_2[0][0]']
#                                 64)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 32,   256        ['conv3d_14[0][0]']
#  ormalization)                  64)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 32, 32, 32,   0           ['batch_normalization_14[0][0]']
#                                 64)
#
#  conv3d_15 (Conv3D)             (None, 32, 32, 32,   110656      ['leaky_re_lu_14[0][0]']
#                                 64)
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 32,   256        ['conv3d_15[0][0]']
#  ormalization)                  64)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 32, 32, 32,   0           ['batch_normalization_15[0][0]']
#                                 64)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 64, 64, 64,   16416      ['leaky_re_lu_15[0][0]']
#  spose)                         32)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_3[0][0]',
#                                 64)                               'leaky_re_lu_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 64, 64, 64,   55328       ['concatenate_3[0][0]']
#                                 32)
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64,   128        ['conv3d_16[0][0]']
#  ormalization)                  32)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 64, 64, 64,   0           ['batch_normalization_16[0][0]']
#                                 32)
#
#  conv3d_17 (Conv3D)             (None, 64, 64, 64,   27680       ['leaky_re_lu_16[0][0]']
#                                 32)
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 64,   128        ['conv3d_17[0][0]']
#  ormalization)                  32)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 64, 64, 64,   0           ['batch_normalization_17[0][0]']
#                                 32)
#
#  conv3d_18 (Conv3D)             (None, 64, 64, 64,   865         ['leaky_re_lu_17[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 22,587,937
# Trainable params: 22,582,049
# Non-trainable params: 5,888
# __________________________________________________________________________________________________
# None

# %%
csv_path = '/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/Final/CSVLogs/3mm_5mm_All_Model.csv'
model_checkpoint_path = '/media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/Final/SavedModels/3mm_5mm_All_Model.hdf5'

# %%
my_callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, mode = 'auto'),
    EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True, mode = 'auto'),
    CSVLogger(csv_path, separator=',', append=True),
    ModelCheckpoint(filepath=model_checkpoint_path,
                    monitor='val_loss',
                    mode='auto',
                    verbose=1,
                    save_best_only= True)
]
#     CustomCallBack()

# %%
model_name = '3mm_5mm_All_Model (300 Epochs)'
# Helper.telegram_bot_sendtext(f'Model {model_name} started training')

history = model.fit(train_array,
                    train_mask_array,
                    batch_size=5,
                    epochs=200,
                    verbose=1,
                    shuffle = True,
                    validation_data=(valid_array, valid_mask_array),
                    callbacks=my_callbacks)
# Out:
# Epoch 1/200
# 2023-03-15 19:10:40.311618: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8301
# 2023-03-15 19:10:41.182060: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 3002/3002 [==============================] - ETA: 0s - loss: 0.7356 - dice_coef: 0.5081
# 2023-03-15 19:15:35.904389: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-03-15 19:15:35.904470: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-03-15 19:15:35.909055: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-03-15 19:15:35.909096: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-03-15 19:15:35.940704: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.18GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-03-15 19:15:35.940745: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.18GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Epoch 00001: val_loss improved from inf to 1.10568, saving model to /media/dro/JHSeagate/FYP/jh_fyp_work/3D_UNet/Final/SavedModels/3mm_5mm_All_Model.hdf5
# 3002/3002 [==============================] - 302s 98ms/step - loss: 0.7356 - dice_coef: 0.5081 - val_loss: 1.1057 - val_dice_coef: 0.2791 - lr: 0.0010
# Epoch 2/200
# 2023-03-15 19:15:36.547304: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 200.06MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2023-03-15 19:15:46.548517: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 320.00MiB (rounded to 335544320)requested by op U-Net/concatenate_3/concat
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-03-15 19:15:46.548584: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2023-03-15 19:15:46.548597: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 249, Chunks in use: 247. 62.2KiB allocated for chunks. 61.8KiB in use in bin. 30.3KiB client-requested in use in bin.
# 2023-03-15 19:15:46.548607: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 82, Chunks in use: 81. 45.5KiB allocated for chunks. 44.8KiB in use in bin. 40.5KiB client-requested in use in bin.
# 2023-03-15 19:15:46.548617: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 82, Chunks in use: 82. 88.2KiB allocated for chunks. 88.2KiB in use in bin. 82.0KiB client-requested in use in bin.
# 2023-03-15 19:15:46.548628: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin
: RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[5,64,64,64,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_2642454/1260166403.py in <module>
#       2 # Helper.telegram_bot_sendtext(f'Model {model_name} started training')
#       3
# ----> 4 history = model.fit(train_array,
#       5                     train_mask_array,
#       6                     batch_size=5,
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[5,64,64,64,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node U-Net/concatenate_3/concat
#  (defined at /home/dro/.local/lib/python3.8/site-packages/keras/backend.py:3224)
# ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_9646]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node U-Net/concatenate_3/concat:
# In[0] U-Net/conv3d_transpose_3/BiasAdd (defined at /home/dro/.local/lib/python3.8/site-packages/keras/layers/convolutional.py:1660)
# In[1] U-Net/leaky_re_lu_1/LeakyRelu (defined at /home/dro/.local/lib/python3.8/site-packages/keras/backend.py:4850)
# In[2] U-Net/concatenate_3/concat/axis:
#
# Operation defined at: (most recent call last)
# >>>   File "/home/dro/anaconda3/envs/jianhoong/lib/python3.8/runpy.py", line 194, in _run_module_as_main
# >>>     return _run_code(code, main_globals, None,
# >>>
# >>>   File "/home/dro/anaconda3/envs/jianhoong/lib/python3.8/runpy.py", line 87, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 846, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 712, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "/home/dro/anaconda3/envs/jianhoong/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "/home/dro/anaconda3/envs/jianhoong/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "/home/dro/anaconda3/envs/jianhoong/lib/python3.8/asyncio/events.py", line 81, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 390, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
# >>>     return super().run_cell(*args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
# >>>     result = self._run_cell(
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
# >>>     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "/tmp/ipykernel_2642454/1260166403.py", line 4, in <module>
# >>>     history = model.fit(train_array,
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/training.py", line 1216, in fit
# >>>     tmp_logs = self.train_function(iterator)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step
# >>>     outputs = model.train_step(data)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
# >>>     y_pred = self(x, training=True)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/functional.py", line 451, in call
# >>>     return self._run_internal_graph(
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
# >>>     outputs = node.layer(*args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/layers/merge.py", line 183, in call
# >>>     return self._merge_function(inputs)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/layers/merge.py", line 528, in _merge_function
# >>>     return backend.concatenate(inputs, axis=self.axis)
# >>>
# >>>   File "/home/dro/.local/lib/python3.8/site-packages/keras/backend.py", line 3224, in concatenate
# >>>     return tf.concat([to_dense(x) for x in tensors], axis)
# >>>
